# %%
num1 = 15
num2 = 15.15
ch = 'a'
str = "string"
print (num1)
print (num2)
print (str)
print(ch)
# Out:
# 15
# 15.15
# string
# a

# %%
a=b=20
print(a)
print(b)
x,y,z=10,15.2,"saturn"
print(x,y,z)
# Out:
# 20
# 20
# 10 15.2 saturn

# %%
a = True 
x = True + 10
y = False + 10
print("x:", x)
print("y:", y)
# Out:
# x: 11
# y: 10

# %%
x=None
print(x)
# Out:
# None

# %%
listItems=["a","b"]
tupleItems=("a","b")
dicItems={'m' : "male", 'f' : "female"}
setItems={"cat","dog"}
print(listItems)
print(tupleItems)
print(dicItems)
print(setItems)
# Out:
# ['a', 'b']
# ('a', 'b')
# {'m': 'male', 'f': 'female'}
# {'dog', 'cat'}

# %%
a=30
b=10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 40
# 20
# 300
# 3.0
# 0
# 590490000000000
# 3

# %%
a=100
b=10
a+=b
print(a)
a-=b
print(a)
a*=b
print(a)
a/=b
print(a)
a%=b
print(a)
a**=b
print(a)
a//=b
print(a)
# Out:
# 110
# 100
# 1000
# 100.0
# 0.0
# 0.0
# 0.0

# %%
if 100 > 20:
    print("saran")
# Out:
# saran

# %%
a=10
b=20
c=10
if a==c :
    print("equal")
if a!=b :
    print("not equal")
if b > a :
    print("b is greater")
if a < b :
    print("a is less than b")
if a<=c :
    print("a is less than or equal to c")
if a>=c :
    print("a is greater than or equal to c")
# Out:
# equal
# not equal
# b is greater
# a is less than b
# a is less than or equal to c
# a is greater than or equal to c

# %%
print(True and True)
print(True or False)
print(not False)
# Out:
# True
# True
# True

# %%
a = 10
b=20
print(a & b)
print(a | b)
print(a ^ b)
print(~a)
# Out:
# 0
# 30
# 30
# -11

# %%
a=10
print(a << 1)
print(a >> 1)
# Out:
# 20
# 5
